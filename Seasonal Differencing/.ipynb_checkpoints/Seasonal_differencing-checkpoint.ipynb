# %% [markdown]
# # Seasonal differencing
#
# Udacity course. https://classroom.udacity.com/courses/ud980/lessons/ff6cb612-1832-4254-8a87-b4defef8dd58/concepts/cb60ce7c-b295-4f3d-ae58-034363863b4c

# %% [markdown]
# ## 1. Understanding the Problem Statement and Dataset
# Our data is in a file calld bookings in 'input' directory.
#
# Our results will show differences between the same months of previous years within the series.
#
# We'll take the seasonal difference instead of the first difference because our data is seasonal.

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
from math import sqrt
from sklearn.metrics import mean_squared_error

#Importing data
df = pd.read_csv('input/bookings.csv')

#Dropping some columns
df = df.drop(['Year'], axis= 1)
df = df.drop(['Month'], axis= 1)

#Printing head
df.head()
# Out:
#    Bookings     Date
# 0       383  01/2006
# 1       366  02/2006
# 2       250  03/2006
# 3       318  04/2006
# 4       334  05/2006

# %% [markdown]
# ## 2. Aggregating dataset at monthly basis

# %%
#Aggregating the dataset at monthly level
df.Timestamp = pd.to_datetime(df.Date,format='%m/%Y') 
df.index = df.Timestamp 
df = df.resample('M').mean()
# Out:
# /home/emi/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access

# %% [markdown]
# Let’s visualize the data to know how it varies over a time period.
#
# This dataset describes the monthly number of bookings over a 10 year period.
# The units are 120 observations.

# %%
plt.figure(figsize=(12,8))
plt.plot(df.index, df['Bookings'], marker='o')
plt.title("Bookings")
plt.grid('on')
plt.show()
# Out:
# /home/emi/anaconda3/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:107: MatplotlibDeprecationWarning: Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %% [markdown]
# ## 3. Plotting seasonal differencing
# This is the difference between the current and previous seasonal period.
#
# Since our data is monthly, the seasonal difference would be between a given period and 12 periods earlier.
#
# Our results will show differences between the same months of previous years within the series.

# %%
import statsmodels.api as sm

series = pd.Series(df['Bookings'])
diff = series.diff(12)
plt.plot(diff)
plt.show()
